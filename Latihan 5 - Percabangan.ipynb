# %% [markdown]
# # UAS Politeknik Krakatau

# %% [markdown]
# - Nama : Fairuz Aufa Dzaki
# - Kelas : TRPL Semester 3
# - Dosen Pengampu : Yudistira Dwi Permana

# %% [markdown]
# ### Percabangan

# %%
nilai = 75

# %% [markdown]
# penjelasan

# %%
# buatlah if output 75 menjadi nilai A
if nilai >= 75:
    print ('A')
# Out:
# A

# %% [markdown]
# penjelasan

# %%
# Buatlah if else output 75 menjadi nilai B
if nilai >= 75:
    print('B')
else:
    print('waduh')
# Out:
# B

# %%
# Buatlah if elif else output 75 menjadi nilai C
if nilai >= 75:
    print('C')
elif nilai >=50:
    print('Jangan Gitu ya lain kali')
else:
    print('waduuh')
# Out:
# C

# %% [markdown]
# penjelasan

# %%
# lengkapkan kode di bawah ini
for i in ['Saya','Suka','RPL']:
    for j in [1,2]:
        print(i,j)

# buatkan output menjadi
# saya 1
# saya 2
# suka 1
# suka 2
# rpl 1
# rpl 2
# Out:
# Saya 1
# Saya 2
# Suka 1
# Suka 2
# RPL 1
# RPL 2

# %% [markdown]
# penjelasan

# %%
# Break Statement
x = ['saya', 'suka', 'rpl', 'tapi', 'boong']
for word in x:
    if word == 'tapi':
       break
    # lengkapi kode di bawah ini
    
    print(word, end='')
# Out:
# sayasukarpl
